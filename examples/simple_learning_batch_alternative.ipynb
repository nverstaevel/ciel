# %%
# %load_ext autoreload
# %autoreload 2
# %load_ext line_profiler
# Out:
# The autoreload extension is already loaded. To reload it, use:
#   %reload_ext autoreload
# The line_profiler extension is already loaded. To reload it, use:
#   %reload_ext line_profiler

# %%
import sys

sys.path.append("..")

import torch
import numpy as np
import matplotlib.pyplot as plt

from scipy.interpolate import griddata

seed = 256
torch.manual_seed(seed)
np.random.seed(seed)

# %% [markdown]
# ## Plotting Utilities

# %%
from matplotlib.patches import Rectangle

def plot_hypercubes(ax, hypercubes: torch.Tensor, color="C0", alpha=0.4):
    for h in hypercubes:
        low, high = h[:, 0], h[:, 1]
        side_lengths = high - low

        patch = Rectangle(low, side_lengths[0], side_lengths[1], facecolor=color, alpha=alpha)
        ax.add_patch(patch)

def plot_as_heatmap(ax, x, y, z, n_points=1000, cmap="viridis", norm=None, interpolation="linear"):
    x_min, x_max = min(x), max(x)
    y_min, y_max = min(y), max(y)
    X, Y = np.meshgrid(np.linspace(x_min, x_max, n_points), np.linspace(y_min, y_max, n_points))
    Z = griddata((x, y), z, (X, Y), method=interpolation)
    pcm = ax.imshow(Z, extent=[x_min, x_max, y_min, y_max], origin="lower", cmap=cmap, norm=norm)
    return pcm

# %% [markdown]
# ## Data Generation

# %%
from torch_mas.data import DataBuffer

device = "cuda"

num_samples = 1000
test_size = 1000
num_features = 2
noise_level = 0.1
X = (torch.rand(num_samples, num_features)-0.5)*5
y = (torch.sin(torch.sqrt(X[:, 0]**2 + X[:, 1]**2)) + torch.randn(X.size(0))*noise_level).unsqueeze(-1)
X_test = (torch.rand(num_samples, num_features)-0.5)*5
y_test = (torch.sin(torch.sqrt(X_test[:, 0]**2 + X_test[:, 1]**2))).unsqueeze(-1)
dataset = DataBuffer(X, y, device=device)

X.shape, y.shape

fig = plt.gcf()
ax = plt.gca()
# pcm = plot_as_heatmap(ax, X_test[:, 0], X_test[:, 1], y_test)
pcm = plot_as_heatmap(ax, X[:, 0], X[:, 1], y)
ax.set_title("Function to learn")
fig.colorbar(pcm)

# %% [markdown]
# ## Model Training

# %%
import time
from copy import deepcopy
from torch_mas.batch_head_alternative import AlternativeBatchHead
from torch_mas.agents.batch_agents_linear_reg_alternative import BatchLinearAgent, BatchLinearAgentSGD

model = AlternativeBatchHead(
    dataset.input_dim,
    dataset.output_dim,
    R=[0.5, 0.4],
    n_epochs=20,
    batch_size=256,
    agents=BatchLinearAgentSGD,
    agents_kwargs={
        "l1": 0.1,
        "alpha": 0.2,
        "memory_length": 10,
        "lr": 3e-2,
        "n_optim_steps": 10
    },
    device=device
)

t = time.time()
model.fit(dataset)
tt = time.time() - t
print(f"Total training time: {tt}s")

print("Number of agents created:", model.agents.n_agents)
# Out:
# Total training time: 2.0479273796081543s
# Number of agents created: 161

# %%
# %lprun -f model.agents.update_model model.fit(dataset)

# %% [markdown]
# ### Agents Visualization

# %%
ax = plt.gca()
ax.scatter(dataset.X.cpu()[:, 0], dataset.X.cpu()[:, 1], marker="o", c="r", alpha=0)
plot_hypercubes(ax, model.agents.hypercubes.detach().cpu().numpy())
ax.set_title("Agents spatial organization")
ax.set_xlabel("X")
ax.set_ylabel("Y")
# Out:
# Text(0, 0.5, 'Y')

# %% [markdown]
# ### Predictions Visualization

# %%
import time

t = time.time()
y_pred = model.predict(X_test.to(device)).cpu()
tt = time.time() - t
tps = tt / X_test.size(0)
print(f"Total Prediction time: {tt}s for {X_test.size(0)} samples")
print(f"Prediction time per sample: {tps}s")

mse = ((y_pred - y_test) ** 2).mean()
print("Root Mean Squared Error:", torch.sqrt(mse).cpu().detach().numpy())

fig = plt.gcf()
ax = plt.gca()
pcm = plot_as_heatmap(ax, X_test[:, 0], X_test[:, 1], y_pred.detach().squeeze(), interpolation="linear", n_points=1000)
fig.colorbar(pcm)
ax.set_title("Predictions on test")
# Out:
# Total Prediction time: 0.0025081634521484375s for 1000 samples
# Prediction time per sample: 2.5081634521484374e-06s
# Root Mean Squared Error: 0.09492589
# Text(0.5, 1.0, 'Predictions on test')

# %%
deepcopy(model)
# Out:
# ---------------------------------------------------------------------------
# RuntimeError                              Traceback (most recent call last)
# Cell In[23], line 1
# ----> 1 deepcopy(model)
#
# File c:\Users\Seladus\miniconda3\envs\finance\lib\copy.py:172, in deepcopy(x, memo, _nil)
#     170                 y = x
#     171             else:
# --> 172                 y = _reconstruct(x, memo, *rv)
#     174 # If is its own copy, don't memoize.
#     175 if y is not x:
#
# File c:\Users\Seladus\miniconda3\envs\finance\lib\copy.py:271, in _reconstruct(x, memo, func, args, state, listiter, dictiter, deepcopy)
#     269 if state is not None:
#     270     if deep:
# --> 271         state = deepcopy(state, memo)
#     272     if hasattr(y, '__setstate__'):
#     273         y.__setstate__(state)
#
# File c:\Users\Seladus\miniconda3\envs\finance\lib\copy.py:146, in deepcopy(x, memo, _nil)
#     144 copier = _deepcopy_dispatch.get(cls)
#     145 if copier is not None:
# --> 146     y = copier(x, memo)
#     147 else:
#     148     if issubclass(cls, type):
#
# File c:\Users\Seladus\miniconda3\envs\finance\lib\copy.py:231, in _deepcopy_dict(x, memo, deepcopy)
#     229 memo[id(x)] = y
#     230 for key, value in x.items():
# --> 231     y[deepcopy(key, memo)] = deepcopy(value, memo)
#     232 return y
#
# File c:\Users\Seladus\miniconda3\envs\finance\lib\copy.py:172, in deepcopy(x, memo, _nil)
#     170                 y = x
#     171             else:
# --> 172                 y = _reconstruct(x, memo, *rv)
#     174 # If is its own copy, don't memoize.
#     175 if y is not x:
#
# File c:\Users\Seladus\miniconda3\envs\finance\lib\copy.py:271, in _reconstruct(x, memo, func, args, state, listiter, dictiter, deepcopy)
#     269 if state is not None:
#     270     if deep:
# --> 271         state = deepcopy(state, memo)
#     272     if hasattr(y, '__setstate__'):
#     273         y.__setstate__(state)
#
# File c:\Users\Seladus\miniconda3\envs\finance\lib\copy.py:146, in deepcopy(x, memo, _nil)
#     144 copier = _deepcopy_dispatch.get(cls)
#     145 if copier is not None:
# --> 146     y = copier(x, memo)
#     147 else:
#     148     if issubclass(cls, type):
#
# File c:\Users\Seladus\miniconda3\envs\finance\lib\copy.py:231, in _deepcopy_dict(x, memo, deepcopy)
#     229 memo[id(x)] = y
#     230 for key, value in x.items():
# --> 231     y[deepcopy(key, memo)] = deepcopy(value, memo)
#     232 return y
#
# File c:\Users\Seladus\miniconda3\envs\finance\lib\copy.py:153, in deepcopy(x, memo, _nil)
#     151 copier = getattr(x, "__deepcopy__", None)
#     152 if copier is not None:
# --> 153     y = copier(memo)
#     154 else:
#     155     reductor = dispatch_table.get(cls)
#
# File c:\Users\Seladus\miniconda3\envs\finance\lib\site-packages\torch\_tensor.py:86, in Tensor.__deepcopy__(self, memo)
#      84     return handle_torch_function(Tensor.__deepcopy__, (self,), self, memo)
#      85 if not self.is_leaf:
# ---> 86     raise RuntimeError(
#      87         "Only Tensors created explicitly by the user "
#      88         "(graph leaves) support the deepcopy protocol at the moment.  "
#      89         "If you were attempting to deepcopy a module, this may be because "
#      90         "of a torch.nn.utils.weight_norm usage, "
#      91         "see https://github.com/pytorch/pytorch/pull/103001"
#      92     )
#      93 if id(self) in memo:
#      94     return memo[id(self)]
#
# RuntimeError: Only Tensors created explicitly by the user (graph leaves) support the deepcopy protocol at the moment.  If you were attempting to deepcopy a module, this may be because of a torch.nn.utils.weight_norm usage, see https://github.com/pytorch/pytorch/pull/103001
